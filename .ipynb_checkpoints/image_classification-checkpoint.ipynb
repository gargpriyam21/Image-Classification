# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
import urllib
#from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urllib.urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 2
sample_id = 5010
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 2:
# Samples: 10000
# Label Counts: {0: 984, 1: 1007, 2: 1010, 3: 995, 4: 1010, 5: 988, 6: 1008, 7: 1026, 8: 987, 9: 985}
# First 20 Labels: [1, 6, 6, 8, 8, 3, 4, 6, 0, 6, 0, 3, 6, 6, 5, 4, 8, 3, 2, 6]
#
# Example of Image 5010:
# Image - Min Value: 0 Max Value: 243
# Image - Shape: (32, 32, 3)
# Label - Label Id: 3 Name: cat

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    # return (x/255.0)
    
    # Normalised [0,1]
    b = (x - np.max(x))/-np.ptp(x)
    return b


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %%
from sklearn.preprocessing import LabelBinarizer
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    
    encoding_size = 10
    encoder = LabelBinarizer().fit(np.arange(encoding_size, dtype=np.float32))
    return encoder.transform(x)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=[None, image_shape[0], image_shape[1], image_shape[2]], name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=[None, n_classes], name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    # Set shape for the input tensor
    iheight = int(x_tensor.shape[1])
    iwidth = int(x_tensor.shape[2])
    idepth = int(x_tensor.shape[3])
    # Set the shape for the convolutional filter (kernel)
    fheight = conv_ksize[0]
    fwidth = conv_ksize[1]
    # Define the padding, lets leave it in Same for now
    padding = 'SAME'
    # Create the strides vector for the convolution
    conv_strides_vector = [1, conv_strides[0], conv_strides[1], 1]
    # Create the pooling size vector
    pool_ksize_vector = [1, pool_ksize[0], pool_ksize[1], 1]
    # Create the pooling strides vector
    pool_strides_vector = [1, pool_strides[0], pool_strides[1], 1]
    # Initialize the weights of the filter to be from a truncated distribution
    filter_weigths = tf.Variable(tf.truncated_normal(shape=[fheight, fwidth, idepth, conv_num_outputs], stddev=0.05))
    # Add the bias
    filter_bias = tf.Variable(tf.zeros(conv_num_outputs))
    # Create the convolution layer
    conv_layer = tf.nn.conv2d(x_tensor, filter_weigths, strides=conv_strides_vector, padding=padding)
    # Add the bias
    conv_layer = tf.nn.bias_add(conv_layer, filter_bias)
    # Apply the non linearity
    conv_layer = tf.nn.relu(conv_layer)
    # Add The maxpooling layer
    conv_layer = tf.nn.max_pool(conv_layer, ksize=pool_ksize_vector, strides=pool_strides_vector, padding=padding)
    return conv_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    iheight = int(x_tensor.shape[1])
    iwidth = int(x_tensor.shape[2])
    idepth = int(x_tensor.shape[3])
    # Calculate the size of the flattened image
    flattened = iheight*iwidth*idepth
    # reshape the 4d tensor to a 2d tensor
    return tf.reshape(x_tensor,[-1, flattened])


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    iwidth = int(x_tensor.get_shape()[1])
    # Initialize the weights of the fully connected layer
    layer_weigths = tf.Variable(tf.truncated_normal(shape=[iwidth, num_outputs], stddev=0.05))
    #Initialize the biases to be zero for the fully connected layer
    layer_bias = tf.Variable(tf.zeros(num_outputs))
    # Define the layer's output
    layer_out = tf.nn.relu(tf.add(tf.matmul(x_tensor, layer_weigths), layer_bias))
    return layer_out

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function

    iwidth = int(x_tensor.get_shape()[1])
    # Initialize the weights of the fully connected layer
    layer_weigths = tf.Variable(tf.truncated_normal(shape=[iwidth, num_outputs], stddev=0.05))
    #Initialize the biases to be zero for the fully connected layer
    layer_bias = tf.Variable(tf.zeros(num_outputs))
    # Define the layer's output
    layer_output = tf.add(tf.matmul(x_tensor, layer_weigths), layer_bias)
    return layer_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    # Define parameters for the first convolutional layer
    first_conv_output = 32
    first_conv_ksize = [4, 4]
    first_conv_strides = [1, 1]
    first_pool_ksize=[3, 3]
    first_pool_strides = [2, 2]
    
    # Define parameters for the second convolutional layer
    second_conv_output = 16
    second_conv_ksize = [4, 4]
    second_conv_strides = [1, 1]
    second_pool_ksize=[3, 3]
    second_pool_strides = [2, 2]
    
    # Parameters for the fully connected layers
    fconnected_size_1 = 128
    fconnected_size_2 = 64
    
    num_outputs = 10
    
    # First Layer
    first_conv_layer = conv2d_maxpool(x, 
                                      first_conv_output, 
                                      first_conv_ksize, 
                                      first_conv_strides, 
                                      first_pool_ksize, 
                                      first_pool_strides)
    # Second Layer
    second_conv_layer = conv2d_maxpool(first_conv_layer, 
                                      second_conv_output, 
                                      second_conv_ksize, 
                                      second_conv_strides, 
                                      second_pool_ksize, 
                                      second_pool_strides)
    
    # Prepare for flattening
    last_conv_layer = second_conv_layer
    # Flatten
    flattened_layer = flatten(last_conv_layer)
    # First fully connected layer
    fully_connected_layer_1 = fully_conn(flattened_layer, fconnected_size_1)
    # Second fully connected layer
    fully_connected_layer_2 = fully_conn(fully_connected_layer_1, fconnected_size_2)
    # Output layer
    last_output = output(fully_connected_layer_1, num_outputs)
    return last_output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# WARNING:tensorflow:From <ipython-input-12-a29e8ed773a3>:80: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.
#
# Neural Network Built!

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    # Create the feeding dictionary for trainning
    f_dict = {x: feature_batch, y: label_batch, keep_prob: keep_probability}
    session.run(optimizer, feed_dict=f_dict)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    train_loss = session.run(cost,
                       feed_dict={
                           x: feature_batch, 
                           y: label_batch,
                           keep_prob: 1.0})
    
    train_accuracy= session.run(accuracy,
                             feed_dict={
                                 x: feature_batch, 
                                 y: label_batch,
                                 keep_prob: 1.0})
    
    
    valid_loss = session.run(cost,
                          feed_dict={
                              x: valid_features,
                              y: valid_labels,
                              keep_prob: 1.0})
    
    valid_accuracy = session.run(accuracy,
                       feed_dict={
                           x: valid_features, 
                           y: valid_labels,
                           keep_prob: 1.0})
    
    print('Train Loss & Accuracy - {:0.4f} & {:0.4f} and Validate Loss & Accuracy - {:0.4f} & {:0.4f}'.format(train_loss, train_accuracy, valid_loss, valid_accuracy))

# %%
# TODO: Tune Parameters
epochs = 40
batch_size = 3000
keep_probability = 0.65

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print 'Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i)
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 10.4738 & 0.1137 and Validate Loss & Accuracy - 10.7162 & 0.1126
# Epoch  2, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 4.0372 & 0.1480 and Validate Loss & Accuracy - 4.0779 & 0.1228
# Epoch  3, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 2.7933 & 0.1290 and Validate Loss & Accuracy - 2.8014 & 0.1178
# Epoch  4, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 2.3994 & 0.1363 and Validate Loss & Accuracy - 2.4018 & 0.1272
# Epoch  5, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 2.3275 & 0.1127 and Validate Loss & Accuracy - 2.3269 & 0.1064
# Epoch  6, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 2.3100 & 0.1103 and Validate Loss & Accuracy - 2.3101 & 0.1092
# Epoch  7, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 2.3043 & 0.1017 and Validate Loss & Accuracy - 2.3068 & 0.1030
# Epoch  8, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 2.3011 & 0.1040 and Validate Loss & Accuracy - 2.3048 & 0.1106
# Epoch  9, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 2.2992 & 0.1143 and Validate Loss & Accuracy - 2.3028 & 0.1182
# Epoch 10, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 2.2977 & 0.1223 and Validate Loss & Accuracy - 2.3009 & 0.1258
# Epoch 11, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 2.2965 & 0.1220 and Validate Loss & Accuracy - 2.2994 & 0.1334
# Epoch 12, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 2.2953 & 0.1283 and Validate Loss & Accuracy - 2.2984 & 0.1384
# Epoch 13, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 2.2943 & 0.1320 and Validate Loss & Accuracy - 2.2974 & 0.1464
# Epoch 14, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 2.2929 & 0.1300 and Validate Loss & Accuracy - 2.2963 & 0.1478
# Epoch 15, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 2.2911 & 0.1360 and Validate Loss & Accuracy - 2.2948 & 0.1492
# Epoch 16, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 2.2887 & 0.1470 and Validate Loss & Accuracy - 2.2926 & 0.1542
# Epoch 17, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 2.2852 & 0.1507 and Validate Loss & Accuracy - 2.2895 & 0.1568
# Epoch 18, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 2.2797 & 0.1547 and Validate Loss & Accuracy - 2.2845 & 0.1570
# Epoch 19, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 2.2723 & 0.1513 and Validate Loss & Accuracy - 2.2777 & 0.1504
# Epoch 20, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 2.2640 & 0.1430 and Validate Loss & Accuracy - 2.2701 & 0.1422
# Epoch 21, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 2.2552 & 0.1420 and Validate Loss & Accuracy - 2.2618 & 0.1408
# Epoch 22, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 2.2452 & 0.1450 and Validate Loss & Accuracy - 2.2524 & 0.1440
# Epoch 23, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 2.2324 & 0.1580 and Validate Loss & Accuracy - 2.2401 & 0.1618
# Epoch 24, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 2.2166 & 0.1873 and Validate Loss & Accuracy - 2.2251 & 0.1802
# Epoch 25, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 2.1992 & 0.1973 and Validate Loss & Accuracy - 2.2097 & 0.1912
# Epoch 26, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 2.1800 & 0.2073 and Validate Loss & Accuracy - 2.1938 & 0.2000
# Epoch 27, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 2.1567 & 0.2173 and Validate Loss & Accuracy - 2.1744 & 0.1996
# Epoch 28, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 2.1275 & 0.2210 and Validate Loss & Accuracy - 2.1511 & 0.2114
# Epoch 29, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 2.1018 & 0.2340 and Validate Loss & Accuracy - 2.1302 & 0.2210
# Epoch 30, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 2.0707 & 0.2477 and Validate Loss & Accuracy - 2.1000 & 0.2370
# Epoch 31, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 2.0433 & 0.2557 and Validate Loss & Accuracy - 2.0775 & 0.2470
# Epoch 32, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 2.0209 & 0.2620 and Validate Loss & Accuracy - 2.0591 & 0.2582
# Epoch 33, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.9972 & 0.2810 and Validate Loss & Accuracy - 2.0349 & 0.2654
# Epoch 34, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.9761 & 0.2903 and Validate Loss & Accuracy - 2.0198 & 0.2730
# Epoch 35, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.9544 & 0.3020 and Validate Loss & Accuracy - 2.0008 & 0.2834
# Epoch 36, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.9343 & 0.3087 and Validate Loss & Accuracy - 1.9902 & 0.2838
# Epoch 37, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.9122 & 0.3163 and Validate Loss & Accuracy - 1.9737 & 0.2964
# Epoch 38, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.8928 & 0.3257 and Validate Loss & Accuracy - 1.9648 & 0.3030
# Epoch 39, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.8702 & 0.3323 and Validate Loss & Accuracy - 1.9474 & 0.3132
# Epoch 40, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.8493 & 0.3403 and Validate Loss & Accuracy - 1.9357 & 0.3142

# %% [markdown]
# ### Fully Train the Model

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print'Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i)
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 9.4990 & 0.1133 and Validate Loss & Accuracy - 9.5376 & 0.1140
# Epoch  1, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 3.3984 & 0.1197 and Validate Loss & Accuracy - 3.4738 & 0.1196
# Epoch  1, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 2.6227 & 0.1137 and Validate Loss & Accuracy - 2.6331 & 0.1168
# Epoch  1, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 2.3624 & 0.1240 and Validate Loss & Accuracy - 2.3799 & 0.1218
# Epoch  1, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 2.3103 & 0.1280 and Validate Loss & Accuracy - 2.3147 & 0.1178
# Epoch  2, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 2.3031 & 0.1263 and Validate Loss & Accuracy - 2.3048 & 0.1156
# Epoch  2, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 2.3025 & 0.1303 and Validate Loss & Accuracy - 2.3044 & 0.1166
# Epoch  2, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 2.3060 & 0.1190 and Validate Loss & Accuracy - 2.3010 & 0.1210
# Epoch  2, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 2.2967 & 0.1210 and Validate Loss & Accuracy - 2.2962 & 0.1212
# Epoch  2, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 2.2860 & 0.1213 and Validate Loss & Accuracy - 2.2891 & 0.1204
# Epoch  3, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 2.2753 & 0.1270 and Validate Loss & Accuracy - 2.2758 & 0.1362
# Epoch  3, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 2.2617 & 0.1513 and Validate Loss & Accuracy - 2.2556 & 0.1520
# Epoch  3, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 2.2388 & 0.1633 and Validate Loss & Accuracy - 2.2309 & 0.1690
# Epoch  3, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 2.2170 & 0.1793 and Validate Loss & Accuracy - 2.2078 & 0.1850
# Epoch  3, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 2.2038 & 0.1730 and Validate Loss & Accuracy - 2.1875 & 0.2008
# Epoch  4, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 2.1595 & 0.2003 and Validate Loss & Accuracy - 2.1587 & 0.2188
# Epoch  4, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 2.1479 & 0.2293 and Validate Loss & Accuracy - 2.1313 & 0.2314
# Epoch  4, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 2.1059 & 0.2360 and Validate Loss & Accuracy - 2.0988 & 0.2400
# Epoch  4, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 2.0595 & 0.2543 and Validate Loss & Accuracy - 2.0618 & 0.2474
# Epoch  4, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 2.0312 & 0.2683 and Validate Loss & Accuracy - 2.0239 & 0.2622
# Epoch  5, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.9966 & 0.2717 and Validate Loss & Accuracy - 1.9908 & 0.2840
# Epoch  5, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 1.9879 & 0.2920 and Validate Loss & Accuracy - 1.9621 & 0.2906
# Epoch  5, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 1.9428 & 0.3093 and Validate Loss & Accuracy - 1.9357 & 0.2956
# Epoch  5, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 1.9170 & 0.3197 and Validate Loss & Accuracy - 1.9178 & 0.3062
# Epoch  5, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 1.9005 & 0.3210 and Validate Loss & Accuracy - 1.8907 & 0.3152
# Epoch  6, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.8792 & 0.3093 and Validate Loss & Accuracy - 1.8704 & 0.3228
# Epoch  6, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 1.8735 & 0.3317 and Validate Loss & Accuracy - 1.8602 & 0.3322
# Epoch  6, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 1.8356 & 0.3640 and Validate Loss & Accuracy - 1.8321 & 0.3406
# Epoch  6, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 1.8157 & 0.3617 and Validate Loss & Accuracy - 1.8197 & 0.3408
# Epoch  6, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 1.8078 & 0.3570 and Validate Loss & Accuracy - 1.8058 & 0.3454
# Epoch  7, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.7805 & 0.3560 and Validate Loss & Accuracy - 1.7861 & 0.3606
# Epoch  7, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 1.7715 & 0.3720 and Validate Loss & Accuracy - 1.7742 & 0.3628
# Epoch  7, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 1.7447 & 0.3757 and Validate Loss & Accuracy - 1.7529 & 0.3686
# Epoch  7, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 1.7452 & 0.3837 and Validate Loss & Accuracy - 1.7575 & 0.3666
# Epoch  7, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 1.7089 & 0.3943 and Validate Loss & Accuracy - 1.7192 & 0.3818
# Epoch  8, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.7004 & 0.3923 and Validate Loss & Accuracy - 1.7051 & 0.3822
# Epoch  8, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 1.6762 & 0.4010 and Validate Loss & Accuracy - 1.6955 & 0.3824
# Epoch  8, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 1.6601 & 0.4053 and Validate Loss & Accuracy - 1.6788 & 0.3960
# Epoch  8, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 1.6672 & 0.3940 and Validate Loss & Accuracy - 1.6943 & 0.3860
# Epoch  8, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 1.6639 & 0.4173 and Validate Loss & Accuracy - 1.7009 & 0.3870
# Epoch  9, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.6476 & 0.3983 and Validate Loss & Accuracy - 1.6665 & 0.3984
# Epoch  9, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 1.6291 & 0.4227 and Validate Loss & Accuracy - 1.6586 & 0.4018
# Epoch  9, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 1.6008 & 0.4173 and Validate Loss & Accuracy - 1.6454 & 0.4016
# Epoch  9, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 1.5919 & 0.4230 and Validate Loss & Accuracy - 1.6417 & 0.3982
# Epoch  9, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 1.6175 & 0.4280 and Validate Loss & Accuracy - 1.6664 & 0.3968
# Epoch 10, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.5789 & 0.4263 and Validate Loss & Accuracy - 1.6118 & 0.4214
# Epoch 10, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 1.5621 & 0.4393 and Validate Loss & Accuracy - 1.6087 & 0.4162
# Epoch 10, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 1.5401 & 0.4397 and Validate Loss & Accuracy - 1.5993 & 0.4222
# Epoch 10, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 1.5459 & 0.4393 and Validate Loss & Accuracy - 1.6149 & 0.4118
# Epoch 10, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 1.5479 & 0.4483 and Validate Loss & Accuracy - 1.5947 & 0.4272
# Epoch 11, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.5410 & 0.4463 and Validate Loss & Accuracy - 1.5837 & 0.4336
# Epoch 11, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 1.5041 & 0.4660 and Validate Loss & Accuracy - 1.5682 & 0.4290
# Epoch 11, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 1.4903 & 0.4587 and Validate Loss & Accuracy - 1.5612 & 0.4400
# Epoch 11, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 1.4685 & 0.4747 and Validate Loss & Accuracy - 1.5574 & 0.4400
# Epoch 11, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 1.5117 & 0.4647 and Validate Loss & Accuracy - 1.5759 & 0.4314
# Epoch 12, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.4941 & 0.4573 and Validate Loss & Accuracy - 1.5510 & 0.4406
# Epoch 12, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 1.4617 & 0.4777 and Validate Loss & Accuracy - 1.5338 & 0.4452
# Epoch 12, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 1.4524 & 0.4750 and Validate Loss & Accuracy - 1.5421 & 0.4404
# Epoch 12, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 1.4355 & 0.4840 and Validate Loss & Accuracy - 1.5296 & 0.4454
# Epoch 12, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 1.4607 & 0.4857 and Validate Loss & Accuracy - 1.5280 & 0.4472
# Epoch 13, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.4518 & 0.4757 and Validate Loss & Accuracy - 1.5212 & 0.4478
# Epoch 13, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 1.4185 & 0.4897 and Validate Loss & Accuracy - 1.5041 & 0.4560
# Epoch 13, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 1.4025 & 0.4890 and Validate Loss & Accuracy - 1.5027 & 0.4522
# Epoch 13, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 1.3950 & 0.4967 and Validate Loss & Accuracy - 1.5004 & 0.4578
# Epoch 13, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 1.4144 & 0.5027 and Validate Loss & Accuracy - 1.5075 & 0.4514
# Epoch 14, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.4223 & 0.4913 and Validate Loss & Accuracy - 1.5086 & 0.4466
# Epoch 14, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 1.3898 & 0.4960 and Validate Loss & Accuracy - 1.4937 & 0.4614
# Epoch 14, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 1.3650 & 0.5103 and Validate Loss & Accuracy - 1.4834 & 0.4580
# Epoch 14, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 1.3623 & 0.5167 and Validate Loss & Accuracy - 1.4830 & 0.4600
# Epoch 14, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 1.3715 & 0.5167 and Validate Loss & Accuracy - 1.4806 & 0.4644
# Epoch 15, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.3879 & 0.4983 and Validate Loss & Accuracy - 1.4893 & 0.4528
# Epoch 15, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 1.3651 & 0.5097 and Validate Loss & Accuracy - 1.4838 & 0.4632
# Epoch 15, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 1.3315 & 0.5297 and Validate Loss & Accuracy - 1.4527 & 0.4702
# Epoch 15, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 1.3412 & 0.5217 and Validate Loss & Accuracy - 1.4734 & 0.4650
# Epoch 15, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 1.3711 & 0.5140 and Validate Loss & Accuracy - 1.4980 & 0.4614
# Epoch 16, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.3656 & 0.5067 and Validate Loss & Accuracy - 1.4818 & 0.4586
# Epoch 16, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 1.3321 & 0.5303 and Validate Loss & Accuracy - 1.4636 & 0.4732
# Epoch 16, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 1.3252 & 0.5257 and Validate Loss & Accuracy - 1.4641 & 0.4788
# Epoch 16, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 1.3297 & 0.5277 and Validate Loss & Accuracy - 1.4609 & 0.4662
# Epoch 16, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 1.3447 & 0.5210 and Validate Loss & Accuracy - 1.4741 & 0.4666
# Epoch 17, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.3256 & 0.5230 and Validate Loss & Accuracy - 1.4549 & 0.4778
# Epoch 17, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 1.3043 & 0.5387 and Validate Loss & Accuracy - 1.4509 & 0.4758
# Epoch 17, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 1.2953 & 0.5343 and Validate Loss & Accuracy - 1.4557 & 0.4718
# Epoch 17, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 1.3230 & 0.5270 and Validate Loss & Accuracy - 1.4627 & 0.4692
# Epoch 17, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 1.2954 & 0.5427 and Validate Loss & Accuracy - 1.4322 & 0.4848
# Epoch 18, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.3055 & 0.5263 and Validate Loss & Accuracy - 1.4511 & 0.4768
# Epoch 18, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 1.2682 & 0.5567 and Validate Loss & Accuracy - 1.4246 & 0.4884
# Epoch 18, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 1.2636 & 0.5453 and Validate Loss & Accuracy - 1.4338 & 0.4820
# Epoch 18, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 1.2785 & 0.5410 and Validate Loss & Accuracy - 1.4375 & 0.4796
# Epoch 18, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 1.3100 & 0.5390 and Validate Loss & Accuracy - 1.4576 & 0.4782
# Epoch 19, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.2882 & 0.5403 and Validate Loss & Accuracy - 1.4491 & 0.4722
# Epoch 19, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 1.2508 & 0.5627 and Validate Loss & Accuracy - 1.4169 & 0.4892
# Epoch 19, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 1.2432 & 0.5610 and Validate Loss & Accuracy - 1.4232 & 0.4878
# Epoch 19, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 1.2425 & 0.5543 and Validate Loss & Accuracy - 1.4130 & 0.4908
# Epoch 19, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 1.2574 & 0.5653 and Validate Loss & Accuracy - 1.4308 & 0.4810
# Epoch 20, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.2394 & 0.5483 and Validate Loss & Accuracy - 1.4119 & 0.4846
# Epoch 20, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 1.2423 & 0.5533 and Validate Loss & Accuracy - 1.4233 & 0.4970
# Epoch 20, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 1.2377 & 0.5700 and Validate Loss & Accuracy - 1.4319 & 0.4856
# Epoch 20, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 1.2431 & 0.5520 and Validate Loss & Accuracy - 1.4338 & 0.4864
# Epoch 20, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 1.2522 & 0.5587 and Validate Loss & Accuracy - 1.4335 & 0.4830
# Epoch 21, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.2503 & 0.5517 and Validate Loss & Accuracy - 1.4342 & 0.4870
# Epoch 21, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 1.2129 & 0.5700 and Validate Loss & Accuracy - 1.4117 & 0.4830
# Epoch 21, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 1.1932 & 0.5893 and Validate Loss & Accuracy - 1.4044 & 0.4944
# Epoch 21, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 1.2060 & 0.5677 and Validate Loss & Accuracy - 1.4019 & 0.4998
# Epoch 21, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 1.2198 & 0.5783 and Validate Loss & Accuracy - 1.4089 & 0.4944
# Epoch 22, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.1860 & 0.5753 and Validate Loss & Accuracy - 1.3900 & 0.5070
# Epoch 22, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 1.1783 & 0.5860 and Validate Loss & Accuracy - 1.3928 & 0.5008
# Epoch 22, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 1.1721 & 0.5930 and Validate Loss & Accuracy - 1.3950 & 0.4994
# Epoch 22, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 1.1984 & 0.5720 and Validate Loss & Accuracy - 1.4136 & 0.4952
# Epoch 22, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 1.2007 & 0.5853 and Validate Loss & Accuracy - 1.3995 & 0.4958
# Epoch 23, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.1922 & 0.5720 and Validate Loss & Accuracy - 1.4068 & 0.5024
# Epoch 23, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 1.1621 & 0.5940 and Validate Loss & Accuracy - 1.3963 & 0.4944
# Epoch 23, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 1.1667 & 0.5983 and Validate Loss & Accuracy - 1.4033 & 0.4964
# Epoch 23, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 1.1706 & 0.5867 and Validate Loss & Accuracy - 1.3854 & 0.5076
# Epoch 23, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 1.1708 & 0.5997 and Validate Loss & Accuracy - 1.3718 & 0.5068
# Epoch 24, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.1426 & 0.5907 and Validate Loss & Accuracy - 1.3723 & 0.5084
# Epoch 24, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 1.1489 & 0.5963 and Validate Loss & Accuracy - 1.4016 & 0.4924
# Epoch 24, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 1.1461 & 0.6043 and Validate Loss & Accuracy - 1.3933 & 0.5040
# Epoch 24, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 1.1485 & 0.5980 and Validate Loss & Accuracy - 1.3797 & 0.5100
# Epoch 24, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 1.1499 & 0.6060 and Validate Loss & Accuracy - 1.3672 & 0.5100
# Epoch 25, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.1226 & 0.5993 and Validate Loss & Accuracy - 1.3634 & 0.5142
# Epoch 25, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 1.1207 & 0.6050 and Validate Loss & Accuracy - 1.3811 & 0.5036
# Epoch 25, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 1.1314 & 0.6167 and Validate Loss & Accuracy - 1.3891 & 0.5062
# Epoch 25, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 1.1299 & 0.6053 and Validate Loss & Accuracy - 1.3775 & 0.5120
# Epoch 25, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 1.1391 & 0.6067 and Validate Loss & Accuracy - 1.3712 & 0.5134
# Epoch 26, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.1179 & 0.6033 and Validate Loss & Accuracy - 1.3664 & 0.5132
# Epoch 26, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 1.1113 & 0.6067 and Validate Loss & Accuracy - 1.3798 & 0.5068
# Epoch 26, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 1.0962 & 0.6257 and Validate Loss & Accuracy - 1.3703 & 0.5094
# Epoch 26, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 1.1065 & 0.6097 and Validate Loss & Accuracy - 1.3595 & 0.5190
# Epoch 26, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 1.1161 & 0.6150 and Validate Loss & Accuracy - 1.3629 & 0.5118
# Epoch 27, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.0991 & 0.6143 and Validate Loss & Accuracy - 1.3626 & 0.5132
# Epoch 27, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 1.1015 & 0.6100 and Validate Loss & Accuracy - 1.3743 & 0.5104
# Epoch 27, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 1.0700 & 0.6290 and Validate Loss & Accuracy - 1.3600 & 0.5104
# Epoch 27, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 1.0960 & 0.6130 and Validate Loss & Accuracy - 1.3544 & 0.5208
# Epoch 27, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 1.0984 & 0.6203 and Validate Loss & Accuracy - 1.3591 & 0.5160
# Epoch 28, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.0744 & 0.6263 and Validate Loss & Accuracy - 1.3542 & 0.5216
# Epoch 28, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 1.0807 & 0.6167 and Validate Loss & Accuracy - 1.3641 & 0.5140
# Epoch 28, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 1.0594 & 0.6287 and Validate Loss & Accuracy - 1.3640 & 0.5140
# Epoch 28, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 1.0776 & 0.6177 and Validate Loss & Accuracy - 1.3493 & 0.5236
# Epoch 28, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 1.0888 & 0.6250 and Validate Loss & Accuracy - 1.3647 & 0.5152
# Epoch 29, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.0717 & 0.6180 and Validate Loss & Accuracy - 1.3581 & 0.5210
# Epoch 29, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 1.0755 & 0.6207 and Validate Loss & Accuracy - 1.3698 & 0.5146
# Epoch 29, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 1.0563 & 0.6313 and Validate Loss & Accuracy - 1.3713 & 0.5120
# Epoch 29, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 1.0615 & 0.6243 and Validate Loss & Accuracy - 1.3495 & 0.5252
# Epoch 29, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 1.0695 & 0.6330 and Validate Loss & Accuracy - 1.3590 & 0.5204
# Epoch 30, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.0604 & 0.6177 and Validate Loss & Accuracy - 1.3549 & 0.5242
# Epoch 30, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 1.0790 & 0.6180 and Validate Loss & Accuracy - 1.3887 & 0.5094
# Epoch 30, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 1.0888 & 0.6177 and Validate Loss & Accuracy - 1.4107 & 0.5012
# Epoch 30, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 1.1132 & 0.6037 and Validate Loss & Accuracy - 1.4167 & 0.5118
# Epoch 30, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 1.0867 & 0.6233 and Validate Loss & Accuracy - 1.3864 & 0.5098
# Epoch 31, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.0575 & 0.6157 and Validate Loss & Accuracy - 1.3598 & 0.5252
# Epoch 31, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 1.0428 & 0.6300 and Validate Loss & Accuracy - 1.3530 & 0.5154
# Epoch 31, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 1.0299 & 0.6360 and Validate Loss & Accuracy - 1.3633 & 0.5224
# Epoch 31, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 1.0706 & 0.6233 and Validate Loss & Accuracy - 1.3758 & 0.5210
# Epoch 31, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 1.0574 & 0.6327 and Validate Loss & Accuracy - 1.3715 & 0.5172
# Epoch 32, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.0427 & 0.6323 and Validate Loss & Accuracy - 1.3575 & 0.5254
# Epoch 32, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 1.0534 & 0.6343 and Validate Loss & Accuracy - 1.3746 & 0.5148
# Epoch 32, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 1.0521 & 0.6303 and Validate Loss & Accuracy - 1.3855 & 0.5184
# Epoch 32, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 1.0395 & 0.6403 and Validate Loss & Accuracy - 1.3756 & 0.5166
# Epoch 32, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 1.0760 & 0.6317 and Validate Loss & Accuracy - 1.4124 & 0.5016
# Epoch 33, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.0164 & 0.6323 and Validate Loss & Accuracy - 1.3359 & 0.5340
# Epoch 33, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 1.0643 & 0.6200 and Validate Loss & Accuracy - 1.3802 & 0.5194
# Epoch 33, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 1.0350 & 0.6410 and Validate Loss & Accuracy - 1.3705 & 0.5208
# Epoch 33, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 1.0807 & 0.6247 and Validate Loss & Accuracy - 1.4359 & 0.5030
# Epoch 33, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 1.0680 & 0.6357 and Validate Loss & Accuracy - 1.3900 & 0.5156
# Epoch 34, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.0662 & 0.6247 and Validate Loss & Accuracy - 1.4094 & 0.5132
# Epoch 34, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 1.0219 & 0.6413 and Validate Loss & Accuracy - 1.3550 & 0.5214
# Epoch 34, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 1.0420 & 0.6337 and Validate Loss & Accuracy - 1.3622 & 0.5166
# Epoch 34, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 1.0684 & 0.6187 and Validate Loss & Accuracy - 1.3869 & 0.5186
# Epoch 34, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 1.0408 & 0.6390 and Validate Loss & Accuracy - 1.3580 & 0.5204
# Epoch 35, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 1.0147 & 0.6383 and Validate Loss & Accuracy - 1.3580 & 0.5302
# Epoch 35, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 1.0098 & 0.6453 and Validate Loss & Accuracy - 1.3487 & 0.5304
# Epoch 35, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 1.0041 & 0.6530 and Validate Loss & Accuracy - 1.3513 & 0.5270
# Epoch 35, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 1.0004 & 0.6527 and Validate Loss & Accuracy - 1.3415 & 0.5332
# Epoch 35, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 0.9967 & 0.6570 and Validate Loss & Accuracy - 1.3329 & 0.5336
# Epoch 36, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 0.9804 & 0.6540 and Validate Loss & Accuracy - 1.3497 & 0.5336
# Epoch 36, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 0.9927 & 0.6473 and Validate Loss & Accuracy - 1.3484 & 0.5326
# Epoch 36, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 0.9874 & 0.6590 and Validate Loss & Accuracy - 1.3474 & 0.5286
# Epoch 36, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 0.9901 & 0.6497 and Validate Loss & Accuracy - 1.3437 & 0.5374
# Epoch 36, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 0.9919 & 0.6550 and Validate Loss & Accuracy - 1.3443 & 0.5354
# Epoch 37, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 0.9577 & 0.6617 and Validate Loss & Accuracy - 1.3437 & 0.5384
# Epoch 37, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 0.9807 & 0.6590 and Validate Loss & Accuracy - 1.3452 & 0.5372
# Epoch 37, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 0.9768 & 0.6673 and Validate Loss & Accuracy - 1.3491 & 0.5284
# Epoch 37, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 0.9766 & 0.6620 and Validate Loss & Accuracy - 1.3403 & 0.5362
# Epoch 37, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 0.9796 & 0.6650 and Validate Loss & Accuracy - 1.3470 & 0.5358
# Epoch 38, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 0.9429 & 0.6630 and Validate Loss & Accuracy - 1.3424 & 0.5400
# Epoch 38, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 0.9688 & 0.6627 and Validate Loss & Accuracy - 1.3423 & 0.5410
# Epoch 38, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 0.9703 & 0.6740 and Validate Loss & Accuracy - 1.3514 & 0.5298
# Epoch 38, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 0.9654 & 0.6653 and Validate Loss & Accuracy - 1.3384 & 0.5404
# Epoch 38, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 0.9715 & 0.6683 and Validate Loss & Accuracy - 1.3569 & 0.5342
# Epoch 39, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 0.9339 & 0.6617 and Validate Loss & Accuracy - 1.3430 & 0.5410
# Epoch 39, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 0.9576 & 0.6693 and Validate Loss & Accuracy - 1.3438 & 0.5432
# Epoch 39, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 0.9609 & 0.6743 and Validate Loss & Accuracy - 1.3566 & 0.5346
# Epoch 39, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 0.9527 & 0.6720 and Validate Loss & Accuracy - 1.3361 & 0.5422
# Epoch 39, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 0.9529 & 0.6777 and Validate Loss & Accuracy - 1.3516 & 0.5380
# Epoch 40, CIFAR-10 Batch 1:
# Train Loss & Accuracy - 0.9151 & 0.6717 and Validate Loss & Accuracy - 1.3375 & 0.5448
# Epoch 40, CIFAR-10 Batch 2:
# Train Loss & Accuracy - 0.9333 & 0.6783 and Validate Loss & Accuracy - 1.3368 & 0.5444
# Epoch 40, CIFAR-10 Batch 3:
# Train Loss & Accuracy - 0.9203 & 0.6830 and Validate Loss & Accuracy - 1.3363 & 0.5384
# Epoch 40, CIFAR-10 Batch 4:
# Train Loss & Accuracy - 0.9486 & 0.6633 and Validate Loss & Accuracy - 1.3478 & 0.5408
# Epoch 40, CIFAR-10 Batch 5:
# Train Loss & Accuracy - 0.9593 & 0.6680 and Validate Loss & Accuracy - 1.3715 & 0.5270

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.536833330989
